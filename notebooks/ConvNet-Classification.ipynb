# %%
# Various torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

# torchvision
from torchvision import datasets, transforms

# ------------------------
# get up one directory 
import sys, os
sys.path.append(os.path.abspath('../'))
# ------------------------

# custom packages
import matplotlib.pyplot as plt
import models.aux_funs as maf
import optimizers as op
import regularizers as reg
import train
import math
import utils.configuration as cf
import utils.datasets as ud
from models.mnist_conv import mnist_conv

# %% [markdown]
# # Fix the random seed

# %%
random_seed = 2
cf.seed_torch(random_seed)

# %% [markdown]
# # Configure the experiment

# %%
conf_args = {#
    # data specification
    'data_file':"../../Data",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':False, 'num_workers':4, 'cuda_device':0, 'pin_memory':True, 'train_split':0.95,
    #
    'epochs':100,
    # optimizer
    'delta':1.0, 'lr':0.07, 'lamda_0':0.4, 'lamda_1':0.4, 'optim':"AdaBreg", 'conv_group':True,
    'beta':0.0,
    # initialization
    'sparse_init':0.01, 'r':[1,1,1],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %% [markdown]
# # Initiate the model

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    

model = mnist_conv(**model_kwargs)
best_model = train.best_model(mnist_conv(**model_kwargs).to(conf.device))

# %% [markdown]
# # Weight initialization

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    
def init_weights(conf, model):
    # sparsify
    maf.sparse_bias_uniform_(model, 0,conf.r[0])
    maf.sparse_bias_uniform_(model, 0,conf.r[0],ltype=torch.nn.Conv2d)
    maf.sparse_weight_normal_(model, conf.r[1])
    maf.sparse_weight_normal_(model, conf.r[2],ltype=torch.nn.Conv2d)
    #
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Conv2d, conv_group=conf.conv_group)
    model = model.to(conf.device)
    
    return model

model = init_weights(conf,model)

# %% [markdown]
# # Optimizer

# %%
def init_opt(conf, model):
    # -----------------------------------------------------------------------------------
    # Get access to different model parameters
    # -----------------------------------------------------------------------------------
    weights_conv = maf.get_weights_conv(model)
    weights_linear = maf.get_weights_linear(model)
    biases = maf.get_bias(model)
    
    # -----------------------------------------------------------------------------------
    # Initialize optimizer
    # -----------------------------------------------------------------------------------
    if conf.conv_group:
        reg2 = reg.reg_l1_l2_conv(lamda=conf.lamda_0)
    else:
        reg2 = reg.reg_l1(lamda=conf.lamda_0)
    
    if conf.optim == "SGD":
        opt = torch.optim.SGD(model.parameters(), lr=conf.lr, momentum=conf.beta)
    elif conf.optim == "LinBreg":
        opt = op.LinBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])
    elif conf.optim == "ProxSGD":
        opt = op.ProxSGD([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])            
    elif conf.optim == "AdaBreg":
        opt = op.AdaBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2,'delta':conf.delta},
                           {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1),'delta':conf.delta},
                           {'params': biases, 'lr': conf.lr}])
    elif conf.optim == "L1SGD":
        def weight_reg(model):
            reg1 =  reg.reg_l1(lamda=conf.lamda_1)
        
            loss1 = reg1(model.layers2[0].weight) + reg1(model.layers2[2].weight)
            loss2 = reg2(model.layers1[0].weight) + reg2(model.layers1[3].weight)
            return loss1 + loss2
        
        conf.weight_reg = weight_reg
        
        opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=beta)
    else:
        raise ValueError("Unknown Optimizer specified")

    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=5,threshold=0.01)
    
    return opt, scheduler

# %% [markdown]
# # Dataset

# %%
train_loader, valid_loader, test_loader = ud.get_data_set(conf)

# %% [markdown]
# # History and Runs

# %%
# Initialize history
tracked = ['loss', 'node_sparse']
train_hist = {}
val_hist = {}

# %% [markdown]
# # Training

# %%
# -----------------------------------------------------------------------------------
# Reinit weigts and the corresponding optimizer
# -----------------------------------------------------------------------------------
model = init_weights(conf, model)
opt, scheduler = init_opt(conf, model)

# -----------------------------------------------------------------------------------
# train the model
# -----------------------------------------------------------------------------------
for epoch in range(conf.epochs):
    print(25*"<>")
    print(50*"|")
    print(25*"<>")
    print('Epoch:', epoch)

    # ------------------------------------------------------------------------
    # train step, log the accuracy and loss
    # ------------------------------------------------------------------------
    train_data = train.train_step(conf, model, opt, train_loader)

    # update history
    for key in tracked:
        if key in train_data:
            var_list = train_hist.setdefault(key, [])
            var_list.append(train_data[key])           

    # ------------------------------------------------------------------------
    # validation step
    val_data = train.validation_step(conf, model, opt, valid_loader)

    # update validation history
    for key in tracked:
        if key in val_data:
            var = val_data[key]
            if isinstance(var, list):
                for i, var_loc in enumerate(var):
                    key_loc = key+"_" + str(i)
                    var_list = val_hist.setdefault(key_loc, [])
                    val_hist[key_loc].append(var_loc)
            else:
                var_list = val_hist.setdefault(key, [])
                var_list.append(var)   


    scheduler.step(train_data['loss'])
    print("Learning rate:",opt.param_groups[0]['lr'])
    best_model(train_data['acc'], val_data['acc'], model=model)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 0
# --------------------------------------------------
# Train Accuracy: 0.0983859649122807
# Train Loss: 1029.0410108566284
# --------------------------------------------------
# Validation Accuracy: 0.105
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 1
# --------------------------------------------------
# Train Accuracy: 0.09905263157894736
# Train Loss: 1029.1359975337982
# --------------------------------------------------
# Validation Accuracy: 0.09966666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 2
# --------------------------------------------------
# Train Accuracy: 0.09954385964912281
# Train Loss: 1029.0401537418365
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 3
# --------------------------------------------------
# Train Accuracy: 0.10014035087719299
# Train Loss: 1029.0259511470795
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 4
# --------------------------------------------------
# Train Accuracy: 0.10142105263157895
# Train Loss: 1028.9407629966736
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 5
# --------------------------------------------------
# Train Accuracy: 0.1011578947368421
# Train Loss: 1029.018034696579
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 6
# --------------------------------------------------
# Train Accuracy: 0.10142105263157895
# Train Loss: 1028.714356660843
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 7
# --------------------------------------------------
# Train Accuracy: 0.09824561403508772
# Train Loss: 1027.9178256988525
# --------------------------------------------------
# Validation Accuracy: 0.09966666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 8
# --------------------------------------------------
# Train Accuracy: 0.09968421052631579
# Train Loss: 1028.061224937439
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 9
# --------------------------------------------------
# Train Accuracy: 0.09936842105263158
# Train Loss: 1027.900153875351
# --------------------------------------------------
# Validation Accuracy: 0.105
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 10
# --------------------------------------------------
# Train Accuracy: 0.0987719298245614
# Train Loss: 1028.0570998191833
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 11
# --------------------------------------------------
# Train Accuracy: 0.09926315789473684
# Train Loss: 1028.008311510086
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.035
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 12
# --------------------------------------------------
# Train Accuracy: 0.102
# Train Loss: 1028.01757645607
# --------------------------------------------------
# Validation Accuracy: 0.105
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 13
# --------------------------------------------------
# Train Accuracy: 0.0989298245614035
# Train Loss: 1027.4717588424683
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 14
# --------------------------------------------------
# Train Accuracy: 0.10073684210526315
# Train Loss: 1027.4654400348663
# --------------------------------------------------
# Validation Accuracy: 0.10466666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 15
# --------------------------------------------------
# Train Accuracy: 0.09887719298245615
# Train Loss: 1027.5006296634674
# --------------------------------------------------
# Validation Accuracy: 0.10466666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 16
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1027.474826335907
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 17
# --------------------------------------------------
# Train Accuracy: 0.0988421052631579
# Train Loss: 1027.505945444107
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0175
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 18
# --------------------------------------------------
# Train Accuracy: 0.09949122807017544
# Train Loss: 1027.5386667251587
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 19
# --------------------------------------------------
# Train Accuracy: 0.1003859649122807
# Train Loss: 1027.2633728981018
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 20
# --------------------------------------------------
# Train Accuracy: 0.09936842105263158
# Train Loss: 1027.304773569107
# --------------------------------------------------
# Validation Accuracy: 0.09966666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 21
# --------------------------------------------------
# Train Accuracy: 0.0982280701754386
# Train Loss: 1027.2510032653809
# --------------------------------------------------
# Validation Accuracy: 0.105
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 22
# --------------------------------------------------
# Train Accuracy: 0.10068421052631579
# Train Loss: 1027.1711068153381
# --------------------------------------------------
# Validation Accuracy: 0.101
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 23
# --------------------------------------------------
# Train Accuracy: 0.09933333333333333
# Train Loss: 1027.235239982605
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 24
# --------------------------------------------------
# Train Accuracy: 0.10003508771929824
# Train Loss: 1027.213790655136
# --------------------------------------------------
# Validation Accuracy: 0.101
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 25
# --------------------------------------------------
# Train Accuracy: 0.09756140350877193
# Train Loss: 1027.1090955734253
# --------------------------------------------------
# Validation Accuracy: 0.09966666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 26
# --------------------------------------------------
# Train Accuracy: 0.10156140350877194
# Train Loss: 1027.1138899326324
# --------------------------------------------------
# Validation Accuracy: 0.10466666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 27
# --------------------------------------------------
# Train Accuracy: 0.09857894736842106
# Train Loss: 1027.1173343658447
# --------------------------------------------------
# Validation Accuracy: 0.10466666666666667
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 28
# --------------------------------------------------
# Train Accuracy: 0.09791228070175438
# Train Loss: 1027.1235220432281
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 29
# --------------------------------------------------
# Train Accuracy: 0.09601754385964913
# Train Loss: 1027.1097486019135
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.004375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 30
# --------------------------------------------------
# Train Accuracy: 0.09940350877192983
# Train Loss: 1027.0779826641083
# --------------------------------------------------
# Validation Accuracy: 0.101
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 31
# --------------------------------------------------
# Train Accuracy: 0.09787719298245615
# Train Loss: 1027.0686748027802
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 32
# --------------------------------------------------
# Train Accuracy: 0.10036842105263158
# Train Loss: 1027.039873123169
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 33
# --------------------------------------------------
# Train Accuracy: 0.09994736842105263
# Train Loss: 1027.0243463516235
# --------------------------------------------------
# Validation Accuracy: 0.105
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 34
# --------------------------------------------------
# Train Accuracy: 0.0988421052631579
# Train Loss: 1027.0448589324951
# --------------------------------------------------
# Validation Accuracy: 0.101
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 35
# --------------------------------------------------
# Train Accuracy: 0.09785964912280702
# Train Loss: 1027.0463154315948
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0021875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 36
# --------------------------------------------------
# Train Accuracy: 0.09850877192982456
# Train Loss: 1027.0438096523285
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 37
# --------------------------------------------------
# Train Accuracy: 0.09885964912280702
# Train Loss: 1027.0085866451263
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 38
# --------------------------------------------------
# Train Accuracy: 0.09917543859649122
# Train Loss: 1026.9917991161346
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 39
# --------------------------------------------------
# Train Accuracy: 0.09698245614035088
# Train Loss: 1027.0039973258972
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 40
# --------------------------------------------------
# Train Accuracy: 0.10091228070175438
# Train Loss: 1026.9945471286774
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 41
# --------------------------------------------------
# Train Accuracy: 0.09908771929824561
# Train Loss: 1026.997623682022
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00109375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 42
# --------------------------------------------------
# Train Accuracy: 0.09975438596491228
# Train Loss: 1026.9934539794922
# --------------------------------------------------
# Validation Accuracy: 0.09733333333333333
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 43
# --------------------------------------------------
# Train Accuracy: 0.09836842105263158
# Train Loss: 1026.9802470207214
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 44
# --------------------------------------------------
# Train Accuracy: 0.099
# Train Loss: 1026.9797315597534
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 45
# --------------------------------------------------
# Train Accuracy: 0.09817543859649122
# Train Loss: 1026.9803719520569
# --------------------------------------------------
# Validation Accuracy: 0.099
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 46
# --------------------------------------------------
# Train Accuracy: 0.09736842105263158
# Train Loss: 1026.9805281162262
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 47
# --------------------------------------------------
# Train Accuracy: 0.09814035087719299
# Train Loss: 1026.9823782444
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.000546875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 48
# --------------------------------------------------
# Train Accuracy: 0.09773684210526316
# Train Loss: 1026.978702545166
# --------------------------------------------------
# Validation Accuracy: 0.096
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 49
# --------------------------------------------------
# Train Accuracy: 0.09919298245614035
# Train Loss: 1026.9657678604126
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 50
# --------------------------------------------------
# Train Accuracy: 0.097
# Train Loss: 1026.9664096832275
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 51
# --------------------------------------------------
# Train Accuracy: 0.0996140350877193
# Train Loss: 1026.9658856391907
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 52
# --------------------------------------------------
# Train Accuracy: 0.0983157894736842
# Train Loss: 1026.9656491279602
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 53
# --------------------------------------------------
# Train Accuracy: 0.09947368421052631
# Train Loss: 1026.965990781784
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.0002734375
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 54
# --------------------------------------------------
# Train Accuracy: 0.0989298245614035
# Train Loss: 1026.9671976566315
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 55
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9582619667053
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 56
# --------------------------------------------------
# Train Accuracy: 0.09945614035087719
# Train Loss: 1026.9597296714783
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 57
# --------------------------------------------------
# Train Accuracy: 0.09885964912280702
# Train Loss: 1026.9578802585602
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 58
# --------------------------------------------------
# Train Accuracy: 0.09998245614035088
# Train Loss: 1026.9590337276459
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 59
# --------------------------------------------------
# Train Accuracy: 0.0988421052631579
# Train Loss: 1026.9592499732971
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 0.00013671875
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 60
# --------------------------------------------------
# Train Accuracy: 0.09875438596491228
# Train Loss: 1026.959252357483
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 61
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9553303718567
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 62
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9554665088654
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 63
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9550528526306
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 64
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9553830623627
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 65
# --------------------------------------------------
# Train Accuracy: 0.09975438596491228
# Train Loss: 1026.9553697109222
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 6.8359375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 66
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9554772377014
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 67
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.953294992447
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 68
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9528603553772
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 69
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9532833099365
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 70
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9538896083832
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 71
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9538757801056
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 3.41796875e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 72
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9535217285156
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 73
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9527423381805
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 74
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9527456760406
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 75
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9524714946747
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 76
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9520282745361
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 77
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9528579711914
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 1.708984375e-05
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 78
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9523165225983
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 79
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9516971111298
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 80
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9517016410828
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 81
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9518702030182
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 82
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.952222585678
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 83
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9519140720367
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 8.544921875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 84
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9519753456116
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 85
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9513251781464
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 86
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.951547384262
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 87
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9521763324738
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 88
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9515261650085
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 89
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9520406723022
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 4.2724609375e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 90
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9521408081055
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 2.13623046875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 91
# --------------------------------------------------
# Train Accuracy: 0.10042105263157895
# Train Loss: 1026.9512059688568
# --------------------------------------------------
# Validation Accuracy: 0.092
# Non-zero kernels: 0.010096153846153847
# Linear sparsity: 0.6374516441005803
# Overall sparsity: 0.3614016382344977
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [36.532936096191406, 4769.027282714844, 0.0]
# Learning rate: 2.13623046875e-06
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 92

# %%
print(best_model.best_model)

torch.save(best_model.best_model.state_dict(), '../checkpoints/mnist_conv_sparse_adabreg.pth')

# %%
model = best_model.best_model
model.eval()
# Out:
# mnist_conv(
#   (act_fn): ReLU()
#   (layers1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (layers2): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
train.test(conf, model, test_loader)
# Out:
# --------------------------------------------------
# Test Accuracy: 0.8602
# {'acc': 0.8602, 'loss': 3.965606987476349}
