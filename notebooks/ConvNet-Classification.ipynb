# %%
# Various torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

# torchvision
from torchvision import datasets, transforms

# ------------------------
# get up one directory 
import sys, os
sys.path.append(os.path.abspath('../'))
# ------------------------

# custom packages
import models.aux_funs as maf
import optimizers as op
import regularizers as reg
import train
import math
import utils.configuration as cf
import utils.datasets as ud
from models.mnist_conv import mnist_conv

# %% [markdown]
# # Fix the random seed

# %%
random_seed = 0
cf.seed_torch(random_seed)

# %% [markdown]
# # Configure the experiment

# %%
conf_args = {#
    # data specification
    'data_file':"../../datasets",'train_split':0.95, 'data_set':"Fashion-MNIST", 'download':True,
    # cuda
    'use_cuda':True, 'num_workers':4, 'cuda_device':0, 'pin_memory':True, 'train_split':0.95,
    #
    'epochs':100,
    # optimizer
    'delta':1.0, 'lr':0.07, 'lamda_0':.5, 'lamda_1':.5, 'optim':"LinBreg", 'conv_group':True,
    'beta':0.0,
    # initialization
    'sparse_init':0.01, 'r':[10.,10.,10.],
    # misc
    'random_seed':random_seed, 'eval_acc':True,
}

conf = cf.Conf(**conf_args)

# %% [markdown]
# # Initiate the model

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    

model = mnist_conv(**model_kwargs)
best_model = train.best_model(mnist_conv(**model_kwargs).to(conf.device))

# %% [markdown]
# # Weight initialization

# %%
model_kwargs = {'mean':conf.data_set_mean, 'std':conf.data_set_std}    
def init_weights(conf, model):
    # sparsify
    maf.sparse_bias_uniform_(model, 0,conf.r[0])
    maf.sparse_bias_uniform_(model, 0,conf.r[0], ltype=torch.nn.Conv2d)
    maf.sparse_weight_normal_(model, conf.r[1])
    maf.sparse_weight_normal_(model, conf.r[2], ltype=torch.nn.Conv2d)
    #
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Conv2d, conv_group=conf.conv_group)
    maf.sparsify_(model, conf.sparse_init, ltype = nn.Linear)
    model = model.to(conf.device)    
    return model

model = init_weights(conf,model)

# %% [markdown]
# # Optimizer

# %%
def init_opt(conf, model):
    # -----------------------------------------------------------------------------------
    # Get access to different model parameters
    # -----------------------------------------------------------------------------------
    weights_conv = maf.get_weights_conv(model)
    weights_linear = maf.get_weights_linear(model)
    biases = maf.get_bias(model)
    
    # -----------------------------------------------------------------------------------
    # Initialize optimizer
    # -----------------------------------------------------------------------------------
    if conf.conv_group:
        reg2 = reg.reg_l1_l2_conv(lamda=conf.lamda_0)
    else:
        reg2 = reg.reg_l1(lamda=conf.lamda_0)
    
    if conf.optim == "SGD":
        opt = torch.optim.SGD(model.parameters(), lr=conf.lr, momentum=conf.beta)
    elif conf.optim == "LinBreg":
        opt = op.LinBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])
    elif conf.optim == "ProxSGD":
        opt = op.ProxSGD([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2, 'momentum':conf.beta,'delta':conf.delta},
                          {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1), 'momentum':conf.beta,'delta':conf.delta},
                          {'params': biases, 'lr': conf.lr, 'momentum':conf.beta}])            
    elif conf.optim == "AdaBreg":
        opt = op.AdaBreg([{'params': weights_conv, 'lr' : conf.lr, 'reg' : reg2,'delta':conf.delta},
                           {'params': weights_linear, 'lr' : conf.lr, 'reg' : reg.reg_l1(lamda=conf.lamda_1),'delta':conf.delta},
                           {'params': biases, 'lr': conf.lr}])
    elif conf.optim == "L1SGD":
        def weight_reg(model):
            reg1 =  reg.reg_l1(lamda=conf.lamda_1)
        
            loss1 = reg1(model.layers2[0].weight) + reg1(model.layers2[2].weight)
            loss2 = reg2(model.layers1[0].weight) + reg2(model.layers1[3].weight)
            return loss1 + loss2
        
        conf.weight_reg = weight_reg
        
        opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=beta)
    else:
        raise ValueError("Unknown Optimizer specified")

    # learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, factor=0.5, patience=5,threshold=0.01)
    
    return opt, scheduler

# %% [markdown]
# # Dataset

# %%
train_loader, valid_loader, test_loader = ud.get_data_set(conf)

# %% [markdown]
# # History and Runs

# %%
# Initialize history
tracked = ['loss', 'node_sparse']
train_hist = {}
val_hist = {}

# %% [markdown]
# # Training

# %%
# -----------------------------------------------------------------------------------
# Reinit weigts and the corresponding optimizer
# -----------------------------------------------------------------------------------
model = init_weights(conf, model)
opt, scheduler = init_opt(conf, model)

# -----------------------------------------------------------------------------------
# train the model
# -----------------------------------------------------------------------------------
for epoch in range(conf.epochs):
    print(25*"<>")
    print(50*"|")
    print(25*"<>")
    print('Epoch:', epoch)

    # ------------------------------------------------------------------------
    # train step, log the accuracy and loss
    # ------------------------------------------------------------------------
    train_data = train.train_step(conf, model, opt, train_loader)

    # update history
    for key in tracked:
        if key in train_data:
            var_list = train_hist.setdefault(key, [])
            var_list.append(train_data[key])           

    # ------------------------------------------------------------------------
    # validation step
    val_data = train.validation_step(conf, model, opt, valid_loader)

    # update validation history
    for key in tracked:
        if key in val_data:
            var = val_data[key]
            if isinstance(var, list):
                for i, var_loc in enumerate(var):
                    key_loc = key+"_" + str(i)
                    var_list = val_hist.setdefault(key_loc, [])
                    val_hist[key_loc].append(var_loc)
            else:
                var_list = val_hist.setdefault(key, [])
                var_list.append(var)   


    scheduler.step(train_data['loss'])
    print("Learning rate:",opt.param_groups[0]['lr'])
    best_model(train_data['acc'], val_data['acc'], model=model)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 0
# --------------------------------------------------
# Train Accuracy: 0.47871929824561404
# Train Loss: 641.8048565983772
# --------------------------------------------------
# Validation Accuracy: 0.6036666666666667
# Non-zero kernels: 0.011778846153846154
# Linear sparsity: 0.011560082205029014
# Overall sparsity: 0.011656343081505552
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [212.92439222335815, 251.7631950378418, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 1
# --------------------------------------------------
# Train Accuracy: 0.6621052631578948
# Train Loss: 414.35502302646637
# --------------------------------------------------
# Validation Accuracy: 0.673
# Non-zero kernels: 0.012980769230769231
# Linear sparsity: 0.011877417794970986
# Overall sparsity: 0.012362916328188464
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [214.76234197616577, 255.9579610824585, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 2
# --------------------------------------------------
# Train Accuracy: 0.6862982456140351
# Train Loss: 378.44636219739914
# --------------------------------------------------
# Validation Accuracy: 0.615
# Non-zero kernels: 0.013942307692307693
# Linear sparsity: 0.012179642166344293
# Overall sparsity: 0.012955253181695098
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [217.51635074615479, 259.5510444641113, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 3
# --------------------------------------------------
# Train Accuracy: 0.7082105263157895
# Train Loss: 347.86089876294136
# --------------------------------------------------
# Validation Accuracy: 0.696
# Non-zero kernels: 0.015384615384615385
# Linear sparsity: 0.013108982108317214
# Overall sparsity: 0.014110310046033036
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [220.21743535995483, 264.9035987854004, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 4
# --------------------------------------------------
# Train Accuracy: 0.7404035087719298
# Train Loss: 306.85728138685226
# --------------------------------------------------
# Validation Accuracy: 0.712
# Non-zero kernels: 0.015384615384615385
# Linear sparsity: 0.013705875241779497
# Overall sparsity: 0.01444455727051178
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [222.17990159988403, 270.7340908050537, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 5
# --------------------------------------------------
# Train Accuracy: 0.7630175438596491
# Train Loss: 280.6595244705677
# --------------------------------------------------
# Validation Accuracy: 0.7133333333333334
# Non-zero kernels: 0.016346153846153847
# Linear sparsity: 0.014015655222437137
# Overall sparsity: 0.01504112510154346
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [224.765305519104, 274.58409881591797, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 6
# --------------------------------------------------
# Train Accuracy: 0.7794736842105263
# Train Loss: 263.3963894844055
# --------------------------------------------------
# Validation Accuracy: 0.7033333333333334
# Non-zero kernels: 0.016826923076923076
# Linear sparsity: 0.01433299081237911
# Overall sparsity: 0.01543037503384782
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [226.885187625885, 278.3277816772461, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 7
# --------------------------------------------------
# Train Accuracy: 0.7937894736842105
# Train Loss: 247.78529274463654
# --------------------------------------------------
# Validation Accuracy: 0.769
# Non-zero kernels: 0.017788461538461538
# Linear sparsity: 0.0144463249516441
# Overall sparsity: 0.015916937449228268
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [229.25220251083374, 280.9669494628906, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 8
# --------------------------------------------------
# Train Accuracy: 0.8064736842105263
# Train Loss: 234.8414008617401
# --------------------------------------------------
# Validation Accuracy: 0.7833333333333333
# Non-zero kernels: 0.01826923076923077
# Linear sparsity: 0.01472588249516441
# Overall sparsity: 0.016285032493907392
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [231.0488224029541, 283.59990310668945, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 9
# --------------------------------------------------
# Train Accuracy: 0.8139473684210526
# Train Loss: 225.18563231825829
# --------------------------------------------------
# Validation Accuracy: 0.798
# Non-zero kernels: 0.01875
# Linear sparsity: 0.014846772243713733
# Overall sparsity: 0.01656427701056052
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [232.55184412002563, 285.9169578552246, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 10
# --------------------------------------------------
# Train Accuracy: 0.8208070175438597
# Train Loss: 217.5337920486927
# --------------------------------------------------
# Validation Accuracy: 0.8136666666666666
# Non-zero kernels: 0.019230769230769232
# Linear sparsity: 0.015012995647969053
# Overall sparsity: 0.016868907392363932
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [234.25804138183594, 288.0279655456543, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 11
# --------------------------------------------------
# Train Accuracy: 0.8255438596491228
# Train Loss: 212.11625719070435
# --------------------------------------------------
# Validation Accuracy: 0.798
# Non-zero kernels: 0.020192307692307693
# Linear sparsity: 0.015300108800773694
# Overall sparsity: 0.017452782290820472
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [236.58869743347168, 290.3198471069336, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 12
# --------------------------------------------------
# Train Accuracy: 0.8279122807017544
# Train Loss: 207.1191286444664
# --------------------------------------------------
# Validation Accuracy: 0.8236666666666667
# Non-zero kernels: 0.020432692307692308
# Linear sparsity: 0.015556999516441006
# Overall sparsity: 0.017702409964798268
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [238.14757347106934, 292.5934867858887, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 13
# --------------------------------------------------
# Train Accuracy: 0.8335087719298245
# Train Loss: 200.80576166510582
# --------------------------------------------------
# Validation Accuracy: 0.8116666666666666
# Non-zero kernels: 0.020913461538461537
# Linear sparsity: 0.01570811170212766
# Overall sparsity: 0.017998578391551584
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [239.49419975280762, 295.080997467041, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 14
# --------------------------------------------------
# Train Accuracy: 0.8396666666666667
# Train Loss: 196.9336392581463
# --------------------------------------------------
# Validation Accuracy: 0.8346666666666667
# Non-zero kernels: 0.02139423076923077
# Linear sparsity: 0.015897001934235978
# Overall sparsity: 0.01831590170593014
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [241.41396760940552, 297.237247467041, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 15
# --------------------------------------------------
# Train Accuracy: 0.8420350877192982
# Train Loss: 191.9724090397358
# --------------------------------------------------
# Validation Accuracy: 0.8176666666666667
# Non-zero kernels: 0.022115384615384617
# Linear sparsity: 0.016146337040618956
# Overall sparsity: 0.018772847278635256
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [242.5052261352539, 299.2130317687988, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 16
# --------------------------------------------------
# Train Accuracy: 0.8453333333333334
# Train Loss: 189.62900722026825
# --------------------------------------------------
# Validation Accuracy: 0.7973333333333333
# Non-zero kernels: 0.023317307692307693
# Linear sparsity: 0.016395672147001935
# Overall sparsity: 0.019441341727592744
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [244.25664901733398, 300.9525718688965, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 17
# --------------------------------------------------
# Train Accuracy: 0.8450350877192983
# Train Loss: 186.654695764184
# --------------------------------------------------
# Validation Accuracy: 0.8373333333333334
# Non-zero kernels: 0.022596153846153846
# Linear sparsity: 0.016788563829787235
# Overall sparsity: 0.019344029244516652
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [245.60844659805298, 302.98273849487305, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 18
# --------------------------------------------------
# Train Accuracy: 0.8487543859649123
# Train Loss: 183.85610873997211
# --------------------------------------------------
# Validation Accuracy: 0.8126666666666666
# Non-zero kernels: 0.023798076923076922
# Linear sparsity: 0.017121010638297872
# Overall sparsity: 0.02005906444624966
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [247.548246383667, 305.0097427368164, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 19
# --------------------------------------------------
# Train Accuracy: 0.8512631578947368
# Train Loss: 180.24185439944267
# --------------------------------------------------
# Validation Accuracy: 0.8426666666666667
# Non-zero kernels: 0.024278846153846154
# Linear sparsity: 0.017377901353965185
# Overall sparsity: 0.020414466558353644
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [248.96281719207764, 307.02437019348145, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 20
# --------------------------------------------------
# Train Accuracy: 0.8541578947368421
# Train Loss: 177.43165405094624
# --------------------------------------------------
# Validation Accuracy: 0.806
# Non-zero kernels: 0.02451923076923077
# Linear sparsity: 0.017642347678916828
# Overall sparsity: 0.020668325209856484
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [250.2694320678711, 309.1983947753906, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 21
# --------------------------------------------------
# Train Accuracy: 0.8561228070175438
# Train Loss: 175.35175237059593
# --------------------------------------------------
# Validation Accuracy: 0.8466666666666667
# Non-zero kernels: 0.02451923076923077
# Linear sparsity: 0.018088128626692457
# Overall sparsity: 0.02091795288383428
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [251.91495656967163, 311.3523597717285, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 22
# --------------------------------------------------
# Train Accuracy: 0.8581228070175438
# Train Loss: 172.71660412847996
# --------------------------------------------------
# Validation Accuracy: 0.856
# Non-zero kernels: 0.024278846153846154
# Linear sparsity: 0.018314796905222436
# Overall sparsity: 0.02093910777145952
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [253.24193716049194, 313.2802925109863, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 23
# --------------------------------------------------
# Train Accuracy: 0.8600701754385965
# Train Loss: 169.65290497243404
# --------------------------------------------------
# Validation Accuracy: 0.8256666666666667
# Non-zero kernels: 0.025240384615384616
# Linear sparsity: 0.018662354932301742
# Overall sparsity: 0.021556830490116436
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [254.37997102737427, 315.5333251953125, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 24
# --------------------------------------------------
# Train Accuracy: 0.8617719298245614
# Train Loss: 167.69252079725266
# --------------------------------------------------
# Validation Accuracy: 0.8403333333333334
# Non-zero kernels: 0.02548076923076923
# Linear sparsity: 0.018896578820116056
# Overall sparsity: 0.021793765231519092
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [255.68297386169434, 317.57826232910156, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 25
# --------------------------------------------------
# Train Accuracy: 0.8632631578947368
# Train Loss: 164.86474280059338
# --------------------------------------------------
# Validation Accuracy: 0.8436666666666667
# Non-zero kernels: 0.026442307692307692
# Linear sparsity: 0.019198803191489363
# Overall sparsity: 0.022386102085025724
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [256.96571111679077, 319.6024856567383, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 26
# --------------------------------------------------
# Train Accuracy: 0.8656842105263158
# Train Loss: 162.9861552119255
# --------------------------------------------------
# Validation Accuracy: 0.838
# Non-zero kernels: 0.026442307692307692
# Linear sparsity: 0.019508583172147
# Overall sparsity: 0.022559572163552668
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [258.5320782661438, 321.629638671875, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 27
# --------------------------------------------------
# Train Accuracy: 0.8659298245614035
# Train Loss: 161.66622152924538
# --------------------------------------------------
# Validation Accuracy: 0.837
# Non-zero kernels: 0.026923076923076925
# Linear sparsity: 0.019818363152804643
# Overall sparsity: 0.02294459111833198
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [259.63435888290405, 323.5758743286133, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 28
# --------------------------------------------------
# Train Accuracy: 0.8679649122807017
# Train Loss: 159.53861993551254
# --------------------------------------------------
# Validation Accuracy: 0.849
# Non-zero kernels: 0.026682692307692307
# Linear sparsity: 0.020060142649903287
# Overall sparsity: 0.022974207961007312
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [260.5960440635681, 325.3723793029785, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 29
# --------------------------------------------------
# Train Accuracy: 0.8695438596491228
# Train Loss: 157.85953976213932
# --------------------------------------------------
# Validation Accuracy: 0.8443333333333334
# Non-zero kernels: 0.027403846153846154
# Linear sparsity: 0.020271699709864602
# Overall sparsity: 0.023409998646087192
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [261.75111055374146, 327.40522956848145, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 30
# --------------------------------------------------
# Train Accuracy: 0.8707017543859649
# Train Loss: 156.18476279079914
# --------------------------------------------------
# Validation Accuracy: 0.8573333333333333
# Non-zero kernels: 0.02716346153846154
# Linear sparsity: 0.020505923597678916
# Overall sparsity: 0.023435384511237476
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [263.28025817871094, 329.3735980987549, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 31
# --------------------------------------------------
# Train Accuracy: 0.872280701754386
# Train Loss: 154.33231908082962
# --------------------------------------------------
# Validation Accuracy: 0.8306666666666667
# Non-zero kernels: 0.027644230769230768
# Linear sparsity: 0.020747703094777564
# Overall sparsity: 0.023782324668291364
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [264.4690775871277, 331.38035583496094, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 32
# --------------------------------------------------
# Train Accuracy: 0.8744736842105263
# Train Loss: 152.76342310011387
# --------------------------------------------------
# Validation Accuracy: 0.8293333333333334
# Non-zero kernels: 0.028365384615384615
# Linear sparsity: 0.021042371856866537
# Overall sparsity: 0.024264656106146764
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [265.9800958633423, 333.1033115386963, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 33
# --------------------------------------------------
# Train Accuracy: 0.8757719298245614
# Train Loss: 151.31638941168785
# --------------------------------------------------
# Validation Accuracy: 0.8583333333333333
# Non-zero kernels: 0.028365384615384615
# Linear sparsity: 0.021261484526112186
# Overall sparsity: 0.02438735445437314
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [267.56038188934326, 335.2013473510742, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 34
# --------------------------------------------------
# Train Accuracy: 0.877578947368421
# Train Loss: 149.65153469145298
# --------------------------------------------------
# Validation Accuracy: 0.861
# Non-zero kernels: 0.028365384615384615
# Linear sparsity: 0.02150326402321083
# Overall sparsity: 0.024522745735174656
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [268.1957173347473, 336.9843444824219, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 35
# --------------------------------------------------
# Train Accuracy: 0.8768070175438597
# Train Loss: 148.78898368775845
# --------------------------------------------------
# Validation Accuracy: 0.8383333333333334
# Non-zero kernels: 0.028365384615384615
# Linear sparsity: 0.02164682059961315
# Overall sparsity: 0.024603134308150556
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [269.6110010147095, 338.71302604675293, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 36
# --------------------------------------------------
# Train Accuracy: 0.8784736842105263
# Train Loss: 147.00673945993185
# --------------------------------------------------
# Validation Accuracy: 0.8626666666666667
# Non-zero kernels: 0.02860576923076923
# Linear sparsity: 0.02189615570599613
# Overall sparsity: 0.024848531004603304
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [270.413236618042, 340.6364803314209, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 37
# --------------------------------------------------
# Train Accuracy: 0.8800526315789474
# Train Loss: 145.70943875610828
# --------------------------------------------------
# Validation Accuracy: 0.8443333333333334
# Non-zero kernels: 0.029086538461538462
# Linear sparsity: 0.022168157640232108
# Overall sparsity: 0.02521239507175738
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [271.58413648605347, 342.5548915863037, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 38
# --------------------------------------------------
# Train Accuracy: 0.8798245614035087
# Train Loss: 145.13164038956165
# --------------------------------------------------
# Validation Accuracy: 0.867
# Non-zero kernels: 0.02860576923076923
# Linear sparsity: 0.022561049323017408
# Overall sparsity: 0.025220857026807472
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [272.64243364334106, 344.39016342163086, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 39
# --------------------------------------------------
# Train Accuracy: 0.8809473684210526
# Train Loss: 143.27174453437328
# --------------------------------------------------
# Validation Accuracy: 0.8713333333333333
# Non-zero kernels: 0.029086538461538462
# Linear sparsity: 0.02287082930367505
# Overall sparsity: 0.025605875981586784
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [274.30699348449707, 346.6144027709961, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 40
# --------------------------------------------------
# Train Accuracy: 0.8838245614035087
# Train Loss: 142.41322222352028
# --------------------------------------------------
# Validation Accuracy: 0.8643333333333333
# Non-zero kernels: 0.02956730769230769
# Linear sparsity: 0.023135275628626693
# Overall sparsity: 0.025965509071215812
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [275.68713426589966, 348.62290954589844, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 41
# --------------------------------------------------
# Train Accuracy: 0.8834736842105263
# Train Loss: 140.96144264936447
# --------------------------------------------------
# Validation Accuracy: 0.8596666666666667
# Non-zero kernels: 0.03028846153846154
# Linear sparsity: 0.023482833655705995
# Overall sparsity: 0.026477457351746548
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [276.75601959228516, 350.72970962524414, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 42
# --------------------------------------------------
# Train Accuracy: 0.884859649122807
# Train Loss: 139.32190735638142
# --------------------------------------------------
# Validation Accuracy: 0.8613333333333333
# Non-zero kernels: 0.030528846153846153
# Linear sparsity: 0.023679279497098644
# Overall sparsity: 0.026693237205523964
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [278.45474004745483, 352.8300609588623, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 43
# --------------------------------------------------
# Train Accuracy: 0.8857543859649123
# Train Loss: 138.14019158482552
# --------------------------------------------------
# Validation Accuracy: 0.8586666666666667
# Non-zero kernels: 0.030048076923076924
# Linear sparsity: 0.02394372582205029
# Overall sparsity: 0.026629772542648252
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [279.78919744491577, 355.0266513824463, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 44
# --------------------------------------------------
# Train Accuracy: 0.8868771929824562
# Train Loss: 136.948417365551
# --------------------------------------------------
# Validation Accuracy: 0.8716666666666667
# Non-zero kernels: 0.03028846153846154
# Linear sparsity: 0.024132616054158607
# Overall sparsity: 0.026841321418900624
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [280.6251788139343, 356.85103034973145, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 45
# --------------------------------------------------
# Train Accuracy: 0.8875964912280702
# Train Loss: 135.6625877916813
# --------------------------------------------------
# Validation Accuracy: 0.8533333333333334
# Non-zero kernels: 0.03028846153846154
# Linear sparsity: 0.02433661750483559
# Overall sparsity: 0.026955557812076904
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [282.08829164505005, 358.7648983001709, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 46
# --------------------------------------------------
# Train Accuracy: 0.8882105263157895
# Train Loss: 134.9515644311905
# --------------------------------------------------
# Validation Accuracy: 0.87
# Non-zero kernels: 0.03028846153846154
# Linear sparsity: 0.024661508704061894
# Overall sparsity: 0.02713748984565394
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [283.53708028793335, 361.15327072143555, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 47
# --------------------------------------------------
# Train Accuracy: 0.8883684210526316
# Train Loss: 134.16124241054058
# --------------------------------------------------
# Validation Accuracy: 0.8656666666666667
# Non-zero kernels: 0.030528846153846153
# Linear sparsity: 0.024895732591876208
# Overall sparsity: 0.027374424587056592
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [284.68740940093994, 363.2243118286133, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 48
# --------------------------------------------------
# Train Accuracy: 0.8900877192982456
# Train Loss: 132.64721536636353
# --------------------------------------------------
# Validation Accuracy: 0.8723333333333333
# Non-zero kernels: 0.03125
# Linear sparsity: 0.02520551257253385
# Overall sparsity: 0.027865217979962092
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [285.8792781829834, 365.3738384246826, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 49
# --------------------------------------------------
# Train Accuracy: 0.8917368421052632
# Train Loss: 131.08937303721905
# --------------------------------------------------
# Validation Accuracy: 0.8696666666666667
# Non-zero kernels: 0.031009615384615385
# Linear sparsity: 0.02543218085106383
# Overall sparsity: 0.027886372867587328
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [286.97094440460205, 367.50745391845703, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 50
# --------------------------------------------------
# Train Accuracy: 0.8937894736842106
# Train Loss: 129.8833381384611
# --------------------------------------------------
# Validation Accuracy: 0.862
# Non-zero kernels: 0.03125
# Linear sparsity: 0.025681515957446808
# Overall sparsity: 0.028131769564040076
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [288.0932331085205, 369.6331329345703, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 51
# --------------------------------------------------
# Train Accuracy: 0.8931578947368422
# Train Loss: 128.98764293640852
# --------------------------------------------------
# Validation Accuracy: 0.851
# Non-zero kernels: 0.03173076923076923
# Linear sparsity: 0.02591573984526112
# Overall sparsity: 0.028474478743568916
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [289.36596393585205, 371.67578315734863, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 52
# --------------------------------------------------
# Train Accuracy: 0.8937894736842106
# Train Loss: 128.37551768124104
# --------------------------------------------------
# Validation Accuracy: 0.859
# Non-zero kernels: 0.031490384615384615
# Linear sparsity: 0.026180186170212765
# Overall sparsity: 0.028516788518819388
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [290.03748416900635, 373.6115417480469, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 53
# --------------------------------------------------
# Train Accuracy: 0.8944210526315789
# Train Loss: 127.60380710661411
# --------------------------------------------------
# Validation Accuracy: 0.8733333333333333
# Non-zero kernels: 0.03076923076923077
# Linear sparsity: 0.0265352998065764
# Overall sparsity: 0.02839832114811806
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [291.2291121482849, 375.7282829284668, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 54
# --------------------------------------------------
# Train Accuracy: 0.8965964912280702
# Train Loss: 126.12340041995049
# --------------------------------------------------
# Validation Accuracy: 0.832
# Non-zero kernels: 0.03125
# Linear sparsity: 0.026716634429400386
# Overall sparsity: 0.028711413484971568
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [292.18096256256104, 377.9036445617676, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 55
# --------------------------------------------------
# Train Accuracy: 0.8962631578947369
# Train Loss: 126.18650715053082
# --------------------------------------------------
# Validation Accuracy: 0.867
# Non-zero kernels: 0.031490384615384615
# Linear sparsity: 0.026913080270793036
# Overall sparsity: 0.028927193338748984
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [293.4843587875366, 379.7795104980469, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 56
# --------------------------------------------------
# Train Accuracy: 0.897
# Train Loss: 124.92436861246824
# --------------------------------------------------
# Validation Accuracy: 0.875
# Non-zero kernels: 0.03125
# Linear sparsity: 0.02711708172147002
# Overall sparsity: 0.02893565529379908
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [294.3266463279724, 381.9192428588867, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 57
# --------------------------------------------------
# Train Accuracy: 0.8972631578947369
# Train Loss: 123.60209752619267
# --------------------------------------------------
# Validation Accuracy: 0.8486666666666667
# Non-zero kernels: 0.03125
# Linear sparsity: 0.02734375
# Overall sparsity: 0.0290625846195505
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [295.33284187316895, 383.932373046875, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 58
# --------------------------------------------------
# Train Accuracy: 0.8982631578947369
# Train Loss: 123.13093680143356
# --------------------------------------------------
# Validation Accuracy: 0.8726666666666667
# Non-zero kernels: 0.03173076923076923
# Linear sparsity: 0.027547751450676984
# Overall sparsity: 0.029388369888979148
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [296.18502378463745, 385.99062728881836, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 59
# --------------------------------------------------
# Train Accuracy: 0.8980350877192983
# Train Loss: 122.10093300044537
# --------------------------------------------------
# Validation Accuracy: 0.8813333333333333
# Non-zero kernels: 0.031009615384615385
# Linear sparsity: 0.0277593085106383
# Overall sparsity: 0.029189513945301924
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [297.29621410369873, 387.91637802124023, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 60
# --------------------------------------------------
# Train Accuracy: 0.899719298245614
# Train Loss: 120.58756972849369
# --------------------------------------------------
# Validation Accuracy: 0.8663333333333333
# Non-zero kernels: 0.03245192307692308
# Linear sparsity: 0.027925531914893616
# Overall sparsity: 0.029917242079610072
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [298.4405779838562, 389.7148780822754, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 61
# --------------------------------------------------
# Train Accuracy: 0.9000526315789473
# Train Loss: 120.66028610616922
# --------------------------------------------------
# Validation Accuracy: 0.8576666666666667
# Non-zero kernels: 0.03245192307692308
# Linear sparsity: 0.028227756286266923
# Overall sparsity: 0.030086481180611968
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [299.9829030036926, 391.9989929199219, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 62
# --------------------------------------------------
# Train Accuracy: 0.9007368421052632
# Train Loss: 119.19394601881504
# --------------------------------------------------
# Validation Accuracy: 0.8733333333333333
# Non-zero kernels: 0.03173076923076923
# Linear sparsity: 0.028507313829787235
# Overall sparsity: 0.029925704034660168
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [300.74546813964844, 393.9930305480957, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 63
# --------------------------------------------------
# Train Accuracy: 0.9015964912280702
# Train Loss: 118.23137330263853
# --------------------------------------------------
# Validation Accuracy: 0.87
# Non-zero kernels: 0.03245192307692308
# Linear sparsity: 0.028756648936170214
# Overall sparsity: 0.030382649607365284
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [301.81504011154175, 395.9834976196289, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 64
# --------------------------------------------------
# Train Accuracy: 0.9015087719298246
# Train Loss: 117.91401466727257
# --------------------------------------------------
# Validation Accuracy: 0.8713333333333333
# Non-zero kernels: 0.03293269230769231
# Linear sparsity: 0.028983317214700193
# Overall sparsity: 0.030721127809369076
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [303.03863763809204, 397.76467514038086, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 65
# --------------------------------------------------
# Train Accuracy: 0.9024912280701755
# Train Loss: 117.01654357463121
# --------------------------------------------------
# Validation Accuracy: 0.876
# Non-zero kernels: 0.032692307692307694
# Linear sparsity: 0.02913442940038685
# Overall sparsity: 0.03069997292174384
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [304.00689363479614, 399.7665214538574, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 66
# --------------------------------------------------
# Train Accuracy: 0.9034912280701755
# Train Loss: 116.23218097537756
# --------------------------------------------------
# Validation Accuracy: 0.8756666666666667
# Non-zero kernels: 0.03341346153846154
# Linear sparsity: 0.029345986460348163
# Overall sparsity: 0.03113576360682372
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [304.9341630935669, 401.6176528930664, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 67
# --------------------------------------------------
# Train Accuracy: 0.9047017543859649
# Train Loss: 115.89396899938583
# --------------------------------------------------
# Validation Accuracy: 0.8716666666666667
# Non-zero kernels: 0.03293269230769231
# Linear sparsity: 0.029776656189555127
# Overall sparsity: 0.031165380449499052
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [305.68439245224, 403.4246292114258, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 68
# --------------------------------------------------
# Train Accuracy: 0.9038245614035088
# Train Loss: 115.17538818717003
# --------------------------------------------------
# Validation Accuracy: 0.8623333333333333
# Non-zero kernels: 0.03317307692307692
# Linear sparsity: 0.03015443665377176
# Overall sparsity: 0.03148270376387761
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [307.0081114768982, 405.42452239990234, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 69
# --------------------------------------------------
# Train Accuracy: 0.904578947368421
# Train Loss: 114.63554176688194
# --------------------------------------------------
# Validation Accuracy: 0.8793333333333333
# Non-zero kernels: 0.03317307692307692
# Linear sparsity: 0.030388660541586072
# Overall sparsity: 0.03161386406715407
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [308.0370330810547, 407.72562408447266, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 70
# --------------------------------------------------
# Train Accuracy: 0.9051228070175439
# Train Loss: 114.28437151014805
# --------------------------------------------------
# Validation Accuracy: 0.871
# Non-zero kernels: 0.03341346153846154
# Linear sparsity: 0.030615328820116056
# Overall sparsity: 0.03184656783103168
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [308.92972707748413, 409.7540512084961, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 71
# --------------------------------------------------
# Train Accuracy: 0.9060877192982456
# Train Loss: 112.95367723703384
# --------------------------------------------------
# Validation Accuracy: 0.8673333333333333
# Non-zero kernels: 0.03341346153846154
# Linear sparsity: 0.030917553191489363
# Overall sparsity: 0.032015806932033576
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [309.9240207672119, 411.92557525634766, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 72
# --------------------------------------------------
# Train Accuracy: 0.9056666666666666
# Train Loss: 112.96395429968834
# --------------------------------------------------
# Validation Accuracy: 0.883
# Non-zero kernels: 0.03365384615384615
# Linear sparsity: 0.031189555125725337
# Overall sparsity: 0.032273896561061464
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [311.15930557250977, 414.14874267578125, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 73
# --------------------------------------------------
# Train Accuracy: 0.9073333333333333
# Train Loss: 111.41470165550709
# --------------------------------------------------
# Validation Accuracy: 0.865
# Non-zero kernels: 0.03365384615384615
# Linear sparsity: 0.03139355657640232
# Overall sparsity: 0.032388132954237744
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [312.285680770874, 416.2490043640137, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 74
# --------------------------------------------------
# Train Accuracy: 0.9063333333333333
# Train Loss: 111.06450767815113
# --------------------------------------------------
# Validation Accuracy: 0.8726666666666667
# Non-zero kernels: 0.03413461538461538
# Linear sparsity: 0.03173355899419729
# Overall sparsity: 0.03279007581911725
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [313.000864982605, 418.1470947265625, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 75
# --------------------------------------------------
# Train Accuracy: 0.9089824561403509
# Train Loss: 109.92771539837122
# --------------------------------------------------
# Validation Accuracy: 0.8796666666666667
# Non-zero kernels: 0.03413461538461538
# Linear sparsity: 0.03193756044487427
# Overall sparsity: 0.03290431221229353
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [314.00428771972656, 420.32051849365234, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 76
# --------------------------------------------------
# Train Accuracy: 0.9096491228070176
# Train Loss: 109.34097230434418
# --------------------------------------------------
# Validation Accuracy: 0.8773333333333333
# Non-zero kernels: 0.034375
# Linear sparsity: 0.032270007253384914
# Overall sparsity: 0.0331962496615218
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [315.3818869590759, 422.5597343444824, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 77
# --------------------------------------------------
# Train Accuracy: 0.9088421052631579
# Train Loss: 109.13407327234745
# --------------------------------------------------
# Validation Accuracy: 0.8796666666666667
# Non-zero kernels: 0.03485576923076923
# Linear sparsity: 0.032526897969052226
# Overall sparsity: 0.033551651773625776
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [316.7950773239136, 424.799373626709, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 78
# --------------------------------------------------
# Train Accuracy: 0.9099824561403509
# Train Loss: 107.94118704646826
# --------------------------------------------------
# Validation Accuracy: 0.8816666666666667
# Non-zero kernels: 0.035096153846153846
# Linear sparsity: 0.03281401112185687
# Overall sparsity: 0.03381820335770376
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [317.9044437408447, 427.0325927734375, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 79
# --------------------------------------------------
# Train Accuracy: 0.9114912280701755
# Train Loss: 107.46219392865896
# --------------------------------------------------
# Validation Accuracy: 0.8753333333333333
# Non-zero kernels: 0.035576923076923075
# Linear sparsity: 0.03304823500967118
# Overall sparsity: 0.0341609125372326
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [319.4990372657776, 429.212459564209, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 80
# --------------------------------------------------
# Train Accuracy: 0.911
# Train Loss: 107.370724119246
# --------------------------------------------------
# Validation Accuracy: 0.8843333333333333
# Non-zero kernels: 0.035576923076923075
# Linear sparsity: 0.0332597920696325
# Overall sparsity: 0.03427937990793393
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [319.96540784835815, 431.29122161865234, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 81
# --------------------------------------------------
# Train Accuracy: 0.9111228070175439
# Train Loss: 106.43176944553852
# --------------------------------------------------
# Validation Accuracy: 0.8686666666666667
# Non-zero kernels: 0.035576923076923075
# Linear sparsity: 0.033426015473887814
# Overall sparsity: 0.03437246141348497
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [321.66203022003174, 433.69132232666016, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 82
# --------------------------------------------------
# Train Accuracy: 0.9119824561403509
# Train Loss: 105.42227933555841
# --------------------------------------------------
# Validation Accuracy: 0.889
# Non-zero kernels: 0.03581730769230769
# Linear sparsity: 0.03366023936170213
# Overall sparsity: 0.034609396154887624
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [322.4090051651001, 435.7859649658203, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 83
# --------------------------------------------------
# Train Accuracy: 0.9128070175438596
# Train Loss: 104.94104462862015
# --------------------------------------------------
# Validation Accuracy: 0.8683333333333333
# Non-zero kernels: 0.036057692307692304
# Linear sparsity: 0.033773573500967116
# Overall sparsity: 0.03477863525588952
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [323.75693559646606, 438.02112579345703, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 84
# --------------------------------------------------
# Train Accuracy: 0.9130350877192982
# Train Loss: 104.49138284474611
# --------------------------------------------------
# Validation Accuracy: 0.8823333333333333
# Non-zero kernels: 0.036298076923076926
# Linear sparsity: 0.03406824226305609
# Overall sparsity: 0.03504941781749255
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [325.0143766403198, 440.30345153808594, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 85
# --------------------------------------------------
# Train Accuracy: 0.9127719298245615
# Train Loss: 103.72242347896099
# --------------------------------------------------
# Validation Accuracy: 0.8796666666666667
# Non-zero kernels: 0.03653846153846154
# Linear sparsity: 0.03437802224371373
# Overall sparsity: 0.03532866233414568
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [326.2091827392578, 442.3661422729492, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 86
# --------------------------------------------------
# Train Accuracy: 0.9137894736842105
# Train Loss: 103.0817685648799
# --------------------------------------------------
# Validation Accuracy: 0.873
# Non-zero kernels: 0.036778846153846155
# Linear sparsity: 0.03472558027079304
# Overall sparsity: 0.03562906173842405
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [327.202844619751, 444.3719177246094, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 87
# --------------------------------------------------
# Train Accuracy: 0.9139298245614035
# Train Loss: 102.89596013724804
# --------------------------------------------------
# Validation Accuracy: 0.8686666666666667
# Non-zero kernels: 0.036778846153846155
# Linear sparsity: 0.034891803675048357
# Overall sparsity: 0.03572214324397509
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [328.50518703460693, 446.62049865722656, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 88
# --------------------------------------------------
# Train Accuracy: 0.9143684210526316
# Train Loss: 102.6189530864358
# --------------------------------------------------
# Validation Accuracy: 0.865
# Non-zero kernels: 0.037259615384615384
# Linear sparsity: 0.03516380560928433
# Overall sparsity: 0.03608600731112916
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [329.8522710800171, 448.78303146362305, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 89
# --------------------------------------------------
# Train Accuracy: 0.9147017543859649
# Train Loss: 101.77369006350636
# --------------------------------------------------
# Validation Accuracy: 0.88
# Non-zero kernels: 0.03701923076923077
# Linear sparsity: 0.03541314071566731
# Overall sparsity: 0.036119855131329544
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [330.88972091674805, 451.0454559326172, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 90
# --------------------------------------------------
# Train Accuracy: 0.9160701754385965
# Train Loss: 100.95972284674644
# --------------------------------------------------
# Validation Accuracy: 0.8813333333333333
# Non-zero kernels: 0.0375
# Linear sparsity: 0.0358966997098646
# Overall sparsity: 0.036602186569184944
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [332.6348876953125, 453.5512924194336, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 91
# --------------------------------------------------
# Train Accuracy: 0.9164035087719298
# Train Loss: 100.071761444211
# --------------------------------------------------
# Validation Accuracy: 0.8696666666666667
# Non-zero kernels: 0.0375
# Linear sparsity: 0.03622159090909091
# Overall sparsity: 0.036784118602761984
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [333.3103084564209, 455.9369201660156, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 92
# --------------------------------------------------
# Train Accuracy: 0.9172807017543859
# Train Loss: 100.11374197155237
# --------------------------------------------------
# Validation Accuracy: 0.874
# Non-zero kernels: 0.03774038461538461
# Linear sparsity: 0.0364029255319149
# Overall sparsity: 0.036991436501489304
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [334.82348918914795, 458.23050689697266, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 93
# --------------------------------------------------
# Train Accuracy: 0.9172807017543859
# Train Loss: 99.12442837655544
# --------------------------------------------------
# Validation Accuracy: 0.8833333333333333
# Non-zero kernels: 0.03798076923076923
# Linear sparsity: 0.0367278167311412
# Overall sparsity: 0.03727914297319253
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [335.6695747375488, 460.3936958312988, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 94
# --------------------------------------------------
# Train Accuracy: 0.9172456140350878
# Train Loss: 98.80852172523737
# --------------------------------------------------
# Validation Accuracy: 0.8806666666666667
# Non-zero kernels: 0.03774038461538461
# Linear sparsity: 0.03712826402321083
# Overall sparsity: 0.037397610343893856
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [336.6066265106201, 462.79473876953125, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 95
# --------------------------------------------------
# Train Accuracy: 0.9186315789473685
# Train Loss: 97.80896845459938
# --------------------------------------------------
# Validation Accuracy: 0.8836666666666667
# Non-zero kernels: 0.03822115384615385
# Linear sparsity: 0.03747582205029013
# Overall sparsity: 0.0378037841862984
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [337.8891658782959, 465.1255226135254, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 96
# --------------------------------------------------
# Train Accuracy: 0.9180701754385965
# Train Loss: 97.6611782759428
# --------------------------------------------------
# Validation Accuracy: 0.883
# Non-zero kernels: 0.038461538461538464
# Linear sparsity: 0.0378158244680851
# Overall sparsity: 0.03809995261305172
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [338.7486505508423, 467.7422065734863, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 97
# --------------------------------------------------
# Train Accuracy: 0.9192456140350878
# Train Loss: 97.13676474243402
# --------------------------------------------------
# Validation Accuracy: 0.846
# Non-zero kernels: 0.03894230769230769
# Linear sparsity: 0.03797449226305609
# Overall sparsity: 0.03840035201733008
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [340.01267433166504, 470.1053123474121, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 98
# --------------------------------------------------
# Train Accuracy: 0.9182631578947369
# Train Loss: 96.66201739758253
# --------------------------------------------------
# Validation Accuracy: 0.8743333333333333
# Non-zero kernels: 0.03870192307692308
# Linear sparsity: 0.0382540498065764
# Overall sparsity: 0.038451123747630656
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [341.1492919921875, 472.4732894897461, 0.0]
# Learning rate: 0.07
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# ||||||||||||||||||||||||||||||||||||||||||||||||||
# <><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch: 99
# --------------------------------------------------
# Train Accuracy: 0.9197368421052632
# Train Loss: 95.79627891629934
# --------------------------------------------------
# Validation Accuracy: 0.8776666666666667
# Non-zero kernels: 0.03918269230769231
# Linear sparsity: 0.03865449709864603
# Overall sparsity: 0.038886914432710536
# Node sparsity: [1.0, 1.0]
# Regularization values per group: [342.3766851425171, 475.12318420410156, 0.0]
# Learning rate: 0.07

# %% [markdown]
# # Evaluation

# %%
train.test(conf, best_model.best_model, test_loader)
print(f'Convolution kernel sparsity: {maf.conv_sparsity(best_model.best_model)}')
print(f'Linear sparsity: {maf.linear_sparsity(best_model.best_model)}')
# Out:
# --------------------------------------------------
# Test Accuracy: 0.88
# Convolution kernel sparsity: 0.03581730769230769
# Linear sparsity: 0.03366023936170213
